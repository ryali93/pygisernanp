# %%
from phd_scraper import se_hydrometeo
se_hydrometeo.download(station_code=100113, init_date="2010-01-01", last_date="2020-12-31", to_csv=r"E:\SupportGIS\B20_Grupo3\100113.csv")
# Out:
#   variable            value
# 0      nom  QUEBRADA SHUGAR
# 1     cate              PLU
# 2      lat         -6.68778
# 3      lon        -78.45694
# 4      ico                M
# 5      cod           100113
# 6  cod_old           153108
# 7   estado         DIFERIDO
# 8      alt           3292.7
# Processing: 2010-01-01
# https://www.senamhi.gob.pe/mapas/mapa-estaciones-2/_dato_esta_tipo02.php?estaciones=100113&CBOFiltro=201001&t_e=M&estado=DIFERIDO&cod_old=153108&cate_esta=PLU&alt=3292
# Processing: 2010-02-01
# https://www.senamhi.gob.pe/mapas/mapa-estaciones-2/_dato_esta_tipo02.php?estaciones=100113&CBOFiltro=201002&t_e=M&estado=DIFERIDO&cod_old=153108&cate_esta=PLU&alt=3292
# Processing: 2010-03-01
# https://www.senamhi.gob.pe/mapas/mapa-estaciones-2/_dato_esta_tipo02.php?estaciones=100113&CBOFiltro=201003&t_e=M&estado=DIFERIDO&cod_old=153108&cate_esta=PLU&alt=3292
# Processing: 2010-04-01
# ...
